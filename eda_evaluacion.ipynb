# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_activity = pd.read_csv("Customer Flight Activity.csv")
df_activity.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %%
df_activity.shape
# Out:
# (405624, 10)

# %%
df_activity.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')

# %%
df_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %%
df_activity.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty Number               405624.0  550037.873084  258935.286969  100018.0
# Year                         405624.0    2017.500000       0.500001    2017.0
# Month                        405624.0       6.500000       3.452057       1.0
# Flights Booked               405624.0       4.115052       5.225518       0.0
# Flights with Companions      405624.0       1.031805       2.076869       0.0
# Total Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points Accumulated           405624.0     123.692721     146.599831       0.0
# Points Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar Cost Points Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                    25%       50%        75%       max
# ...

# %%
df_activity.isnull().sum()/df_activity.shape[0]*100
#no hay nulos, pero hay muchos ceros, sin embargo eso quiere decir que los 0 nos dan algún tipo de información, no está vacío
# Out:
# Loyalty Number                 0.0
# Year                           0.0
# Month                          0.0
# Flights Booked                 0.0
# Flights with Companions        0.0
# Total Flights                  0.0
# Distance                       0.0
# Points Accumulated             0.0
# Points Redeemed                0.0
# Dollar Cost Points Redeemed    0.0
# dtype: float64

# %%
df_activity['Year'].unique()
# Out:
# array([2017, 2018], dtype=int64)

# %%
df_activity['Month'].unique()
# Out:
# array([ 1,  9,  2,  3, 11,  4,  5,  7,  6,  8, 10, 12], dtype=int64)

# %%
df_activity.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')

# %%
df_activity['Flights Booked'].unique()
# Out:
# array([ 3, 10,  6,  0,  8, 11,  9,  4,  7,  5,  2,  1, 12, 13, 14, 16, 15,
#        17, 18, 19, 20, 21], dtype=int64)

# %%
df_activity['Flights with Companions'].unique()
# Out:
# array([ 0,  4,  7,  1,  6,  3,  5,  2, 10,  8,  9, 11], dtype=int64)

# %%
df_activity['Total Flights'].unique()
# Out:
# array([ 3, 14,  6,  0, 15, 11, 12, 10,  8,  9,  7,  5, 16,  2,  1, 17, 13,
#        22,  4, 19, 18, 21, 26, 20, 23, 25, 27, 24, 28, 30, 29, 31, 32],
#       dtype=int64)

# %%
df_activity['Distance'].sample(15)
# Out:
# 219854       0
# 370878       0
# 3938         0
# 23358        0
# 404916    1360
# 167841    2142
# 256201    2116
# 109981    5307
# 344092       0
# 1291      3419
# 6574      1316
# 336931       0
# 383193    1729
# 396990    4500
# 203649       0
# Name: Distance, dtype: int64

# %%
df_activity['Points Accumulated'].sample(15) #A simple vista parece que todos los decimales son .00, pero si miras bien
#hay decimales con valor, por lo tanto se queda el float.
# Out:
# 347425    386.0
# 357895      0.0
# 41686       0.0
# 354265    375.0
# 162554    381.0
# 366687      0.0
# 358411    126.0
# 17065       0.0
# 56697       0.0
# 219356      0.0
# 295349     45.0
# 12158       0.0
# 287995      0.0
# 376832      0.0
# 279527      0.0
# Name: Points Accumulated, dtype: float64

# %%
df_activity['Points Redeemed'].isnull().sum()
# Out:
# 0

# %%
df_activity['Dollar Cost Points Redeemed'].unique()
# Out:
# array([ 0, 28, 30, 25, 36, 32, 24, 26, 37, 33, 35, 27, 31, 54, 42, 29, 38,
#        34, 39, 55, 41, 49, 40, 48, 45, 53, 58, 44, 43, 46, 52, 47, 63, 57,
#        62, 51, 50, 64, 56, 61, 65, 60, 68, 59, 66, 69, 67, 71, 70],
#       dtype=int64)

# %%
df_activity[['Points Accumulated','Points Redeemed', 'Dollar Cost Points Redeemed']].sample(15) #es un cálculo de la empresa, los valores no coinciden exactamente, por lo que ambas columnas son necesarias (redeemed)
# Out:
#         Points Accumulated  Points Redeemed  Dollar Cost Points Redeemed
# 403376                78.0                0                            0
# 271373               336.0                0                            0
# 140139                 0.0                0                            0
# 5075                 350.0              343                           28
# 36285                178.0                0                            0
# 175920                 0.0                0                            0
# 358254                 0.0                0                            0
# 234957               105.0                0                            0
# 138260                76.0                0                            0
# 39605                  0.0                0                            0
# 341073                 0.0                0                            0
# 314461                 0.0                0                            0
# ...

# %%
df_activity = df_activity.rename(columns= {'Flights Booked': 'Flights_Booked'})
df_activity = df_activity.rename(columns= {'Loyalty Number': 'Loyalty_Number'})

# %%
df_activity = df_activity.rename(columns= {'Flights with Companions': 'Flights_with_Companions'})
df_activity = df_activity.rename(columns= {'Total Flights': 'Total_Flights'})
df_activity = df_activity.rename(columns= {'Points Accumulated': 'Points_Accumulated'})
df_activity = df_activity.rename(columns= {'Points Redeemed': 'Points_Redeemed'})
df_activity = df_activity.rename(columns= {'Dollar Cost Points Redeemed': 'Dollar_Cost_Points_Redeemed'})

# %%
df_activity.head(2)
# Out:
#    Loyalty_Number  Year  Month  Flights_Booked  Flights_with_Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
#
#    Total_Flights  Distance  Points_Accumulated  Points_Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
#
#    Dollar_Cost_Points_Redeemed
# 0                            0
# 1                            0

# %%
df_activity['Loyalty_Number'].duplicated().sum() #es una columna object, hay que cambiarla a int
# Out:
# 388887

# %%
df_activity['Loyalty_Number'] = df_activity['Loyalty_Number'].astype(int)

# %%
df_activity.duplicated(subset='Loyalty_Number').sum() #reasegurar
# Out:
# 388887

# %%
#keep false para verlos todos
duplicados_number = df_activity[df_activity['Loyalty_Number'].duplicated(keep=False)]
duplicados_number.sort_values('Loyalty_Number').head(20)
# Out:
#         Loyalty_Number  Year  Month  Flights_Booked  Flights_with_Companions  \
# 0               100018  2017      1               3                        0
# 388723          100018  2018     12              17                        6
# 185911          100018  2017     12               6                        0
# 101406          100018  2017      7              10                        0
# 287317          100018  2018      6               0                        0
# 169010          100018  2017     11              13                        1
# 46353           100018  2018     10               6                        4
# 304218          100018  2018      7               9                        7
# 16901           100018  2017      2               2                        2
# 213311          100018  2017      3              14                        3
# 50703           100018  2017      4               4                        0
# ...

# %% [markdown]
# Los duplicados hacen referencia a diferentes compras de vuelos, meses, años, etc. Eso quiere decir que realmente se necesitan ya que ese usuario ha realizado esas reservas de vuelos y aparece el número de fidelidad repetido, pero es necesario.

# %%
df_history = pd.read_csv("Customer Loyalty History.csv")
df_history.head()
# Out:
#    Loyalty Number Country          Province       City Postal Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W 1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y 3Z5    Male
#
#   Education    Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
# ...

# %%
df_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  object
#  9   Loyalty Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  object
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   2067 non-null   float64
# ...

# %%
df_history.describe().T
# Out:
#                       count           mean            std        min  \
# Loyalty Number      16737.0  549735.880445  258912.132453  100018.00
# Salary              12499.0   79245.609409   35008.297285  -58486.00
# CLV                 16737.0    7988.896536    6860.982280    1898.01
# Enrollment Year     16737.0    2015.253211       1.979111    2012.00
# Enrollment Month    16737.0       6.669116       3.398958       1.00
# Cancellation Year    2067.0    2016.503145       1.380743    2013.00
# Cancellation Month   2067.0       6.962748       3.455297       1.00
#
#                           25%        50%        75%        max
# Loyalty Number      326603.00  550434.00  772019.00  999986.00
# Salary               59246.50   73455.00   88517.50  407228.00
# CLV                   3980.84    5780.18    8940.58   83325.38
# Enrollment Year       2014.00    2015.00    2017.00    2018.00
# Enrollment Month         4.00       7.00      10.00      12.00
# ...

# %%
df_history.isnull().sum()/df_history.shape[0]*100 #hay un porcentaje grande de nulos en salary, cancellation year y month. Habrá que ver por qué.
#En cancelation, seguramente, es porque continuarán en la empresa y no habrán cancelado nada.
# Out:
# Loyalty Number         0.000000
# Country                0.000000
# Province               0.000000
# City                   0.000000
# Postal Code            0.000000
# Gender                 0.000000
# Education              0.000000
# Salary                25.321145
# Marital Status         0.000000
# Loyalty Card           0.000000
# CLV                    0.000000
# Enrollment Type        0.000000
# Enrollment Year        0.000000
# Enrollment Month       0.000000
# Cancellation Year     87.650117
# Cancellation Month    87.650117
# dtype: float64

# %%
df_history['Country'].unique() #Posible Drop, no aporta info ya que todo es el mismo país
# Out:
# array(['Canada'], dtype=object)

# %%
df_history['Province'].unique()
# Out:
# array(['Ontario', 'Alberta', 'British Columbia', 'Quebec', 'Yukon',
#        'New Brunswick', 'Manitoba', 'Nova Scotia', 'Saskatchewan',
#        'Newfoundland', 'Prince Edward Island'], dtype=object)

# %%
df_history['City'].unique()
df_history['Postal Code'].unique()
df_history['Gender'].unique()
df_history['Education'].unique() #columna casi correcta, replace los espacios por _
df_history['Marital Status'].unique()
df_history['Loyalty Card'].unique()
df_history['Enrollment Type'].unique()
# Out:
# array(['Standard', '2018 Promotion'], dtype=object)

# %%
#df_history['Enrollment Year'].isna().sum()
df_history['Enrollment Month'].isna().sum() #ninguno de los dos tiene nulos
# Out:
# 0

# %%
df_history['Salary'].tail() #hay valores negativos y NaN
# Out:
# 16732        NaN
# 16733    89210.0
# 16734        NaN
# 16735   -57297.0
# 16736    75049.0
# Name: Salary, dtype: float64

# %%
df_history['CLV'].duplicated().sum()
# Out:
# 8753

# %%
duplicados_history = df_history[df_history['CLV'].duplicated(keep=False)]
duplicados_history.sort_values('CLV').head(20) 
#hay duplicados pero es un comportamiento normal, ya que diferentes clientes tienen el mismo valor por los parámetros que pone la empresa. Son correctos, no hay que eliminarlos.
# Out:
#       Loyalty Number Country          Province            City Postal Code  \
# 9824          365346  Canada            Quebec        Montreal     H4G 3T4
# 9825          975531  Canada          Manitoba        Winnipeg     R6Y 4T5
# 9826          345518  Canada           Ontario         Toronto     P1J 8T7
# 9827          717100  Canada  British Columbia       Vancouver     V5R 1W3
# 9829          990512  Canada           Ontario         Toronto     P1W 1K4
# 9828          174666  Canada  British Columbia       Vancouver     V6E 3D9
# 9831          702482  Canada            Quebec     Quebec City     G1B 3L5
# 9830          678284  Canada       Nova Scotia         Halifax     B3C 2M8
# 9833          932748  Canada            Quebec       Tremblant     H5Y 2S9
# 9832          526508  Canada     New Brunswick         Moncton     E1A 2A7
# 9835          748019  Canada          Manitoba        Winnipeg     R3R 3T4
# ...

# %%
df_history['CLV'].sample(20)
# Out:
# 11564     2678.06
# 9880      2127.92
# 13067     4794.93
# 9213     14635.45
# 9623     23950.37
# 658       4883.55
# 2320      7919.20
# 13317     5049.69
# 16689    35862.99
# 15409     9161.66
# 13138     4869.28
# 4619      2952.36
# 12127     3163.28
# 7787      7713.82
# 7454      7028.94
# 14373     6915.73
# 14585     7432.20
# 8267      8646.50
# 16025    13869.93
# 3265     11638.90
# Name: CLV, dtype: float64

# %%
df_history['Cancellation Year'].unique() #cambiar a object
# Out:
# array([  nan, 2018., 2015., 2017., 2014., 2016., 2013.])

# %%
df_history['Cancellation Year'].isna().sum() #hay un alto porcentaje porque hay poca gente que se haya dado de baja
# Out:
# 14670

# %%
df_history['Cancellation Month'].unique() #cambiar float
# Out:
# array([nan,  1., 12.,  4.,  2.,  7., 11.,  5.,  6., 10.,  8.,  9.,  3.])

# %%
df_history['Cancellation Year'] = df_history['Cancellation Year'].astype(str)
df_history['Cancellation Month'] = df_history['Cancellation Month'].astype(str)

# %%
df_history['Cancellation Month'].dtype
# Out:
# dtype('O')

# %%
df_history['Cancellation Year'].dtype
# Out:
# dtype('O')

# %%
df_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  object
#  9   Loyalty Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  object
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   16737 non-null  object
# ...

# %%
df_history['Cancellation Month'] = df_history["Cancellation Month"].str.split(".").str[0]

# %%
df_history['Cancellation Month'].unique()
# Out:
# array(['nan', '1', '12', '4', '2', '7', '11', '5', '6', '10', '8', '9',
#        '3'], dtype=object)

# %%
df_history['Cancellation Year'] = df_history["Cancellation Year"].str.split(".").str[0]

# %%
df_history['Cancellation Year'].unique()
# Out:
# array(['nan', '2018', '2015', '2017', '2014', '2016', '2013'],
#       dtype=object)

# %%
df_history.drop(columns='Country', axis=1, inplace=True) #inplace True hace lo mismo que guardar la variable

# %%
df_history.head(2)
# Out:
#    Loyalty Number Province      City Postal Code  Gender Education   Salary  \
# 0          480934  Ontario   Toronto     M2Z 4K1  Female  Bachelor  83236.0
# 1          549612  Alberta  Edmonton     T3G 6Y6    Male   College      NaN
#
#   Marital Status Loyalty Card      CLV Enrollment Type  Enrollment Year  \
# 0        Married         Star  3839.14        Standard             2016
# 1       Divorced         Star  3839.61        Standard             2016
#
#    Enrollment Month Cancellation Year Cancellation Month
# 0                 2               nan                nan
# 1                 3               nan                nan

# %%
df_history['Salary']
# Out:
# 0         83236.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4        103495.0
#            ...
# 16732         NaN
# 16733     89210.0
# 16734         NaN
# 16735    -57297.0
# 16736     75049.0
# Name: Salary, Length: 16737, dtype: float64

# %%
df_history['Salary'] = df_history['Salary'].abs() #abs convierte el valor en absoluto y por eso desaparece el negativo
df_history['Salary']
# Out:
# 0         83236.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4        103495.0
#            ...
# 16732         NaN
# 16733     89210.0
# 16734         NaN
# 16735     57297.0
# 16736     75049.0
# Name: Salary, Length: 16737, dtype: float64

# %%
df_history['Education'].unique()
# Out:
# array(['Bachelor', 'College', 'Master', 'High School or Below', 'Doctor'],
#       dtype=object)

# %%
df_history['Education'] = df_history['Education'].replace({"High School or Below":"High_School_or_Below"})

# %%
df_history.columns
# Out:
# Index(['Loyalty Number', 'Province', 'City', 'Postal Code', 'Gender',
#        'Education', 'Salary', 'Marital Status', 'Loyalty Card', 'CLV',
#        'Enrollment Type', 'Enrollment Year', 'Enrollment Month',
#        'Cancellation Year', 'Cancellation Month'],
#       dtype='object')

# %%
dicc_correcto = {'Postal Code': 'Postal_Code',
    'Marital Status': 'Marital_Status',
    'Employment Type': 'Employment_Type',
    'Salary Range': 'Salary_Range',
    'Loyalty Card': 'Loyalty_Card',
    'Enrollment Type': 'Enrollment_Type',
    'Enrollment Year': 'Enrollment_Year',
    'Enrollment Month': 'Enrollment_Month',
    'Cancellation Year': 'Cancellation_Year',
    'Cancellation Month': 'Cancellation_Month',
    'Loyalty Number': 'Loyalty_Number'
    }

# %%
def renombrar_columnas (df, columnas):
    return df.rename(columns=columnas, inplace= True)

# %%
renombrar_columnas(df_history, dicc_correcto)

# %%
df_history.to_csv("Customer_history_clean.csv", index=False)

# %%
df_activity.to_csv("Customer_activity_clean.csv", index=False)

# %%
df_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty_Number               405624 non-null  int32
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights_Booked               405624 non-null  int64
#  4   Flights_with_Companions      405624 non-null  int64
#  5   Total_Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points_Accumulated           405624 non-null  float64
#  8   Points_Redeemed              405624 non-null  int64
#  9   Dollar_Cost_Points_Redeemed  405624 non-null  int64
# dtypes: float64(1), int32(1), int64(8)
# memory usage: 29.4 MB

# %%
df_history.info() #tienen columnas en común (loyalty number), se puede usar merge si se usa "loyalty number" como columna, o join con index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty_Number      16737 non-null  int64
#  1   Province            16737 non-null  object
#  2   City                16737 non-null  object
#  3   Postal_Code         16737 non-null  object
#  4   Gender              16737 non-null  object
#  5   Education           16737 non-null  object
#  6   Salary              12499 non-null  float64
#  7   Marital_Status      16737 non-null  object
#  8   Loyalty_Card        16737 non-null  object
#  9   CLV                 16737 non-null  float64
#  10  Enrollment_Type     16737 non-null  object
#  11  Enrollment_Year     16737 non-null  int64
#  12  Enrollment_Month    16737 non-null  int64
#  13  Cancellation_Year   16737 non-null  object
#  14  Cancellation_Month  16737 non-null  object
# ...

# %%
df_history.head(2)
# Out:
#    Loyalty_Number Province      City Postal_Code  Gender Education   Salary  \
# 0          480934  Ontario   Toronto     M2Z 4K1  Female  Bachelor  83236.0
# 1          549612  Alberta  Edmonton     T3G 6Y6    Male   College      NaN
#
#   Marital_Status Loyalty_Card      CLV Enrollment_Type  Enrollment_Year  \
# 0        Married         Star  3839.14        Standard             2016
# 1       Divorced         Star  3839.61        Standard             2016
#
#    Enrollment_Month Cancellation_Year Cancellation_Month
# 0                 2               nan                nan
# 1                 3               nan                nan

# %%
df_activity.shape
# Out:
# (405624, 10)

# %%
df_history.shape
# Out:
# (16737, 15)

# %%
df_merged = pd.merge(df_activity, df_history, on='Loyalty_Number')

# %%
df_merged
# Out:
#         Loyalty_Number  Year  Month  Flights_Booked  Flights_with_Companions  \
# 0               100018  2017      1               3                        0
# 1               100102  2017      1              10                        4
# 2               100140  2017      1               6                        0
# 3               100214  2017      1               0                        0
# 4               100272  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
# ...

# %%
df_merged.to_csv("Customer_merged.csv", index=False)

# %%
df_merged.describe().T
# Out:
#                                 count           mean            std  \
# Loyalty_Number               405624.0  550037.873084  258935.286969
# Year                         405624.0    2017.500000       0.500001
# Month                        405624.0       6.500000       3.452057
# Flights_Booked               405624.0       4.115052       5.225518
# Flights_with_Companions      405624.0       1.031805       2.076869
# Total_Flights                405624.0       5.146858       6.521227
# Distance                     405624.0    1208.880059    1433.155320
# Points_Accumulated           405624.0     123.692721     146.599831
# Points_Redeemed              405624.0      30.696872     125.486049
# Dollar_Cost_Points_Redeemed  405624.0       2.484503      10.150038
# Salary                       302952.0   79381.440228   34735.904533
# CLV                          405624.0    7991.976226    6863.663857
# Enrollment_Year              405624.0    2015.252529       1.979427
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty_Number               405624 non-null  int32
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights_Booked               405624 non-null  int64
#  4   Flights_with_Companions      405624 non-null  int64
#  5   Total_Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points_Accumulated           405624 non-null  float64
#  8   Points_Redeemed              405624 non-null  int64
#  9   Dollar_Cost_Points_Redeemed  405624 non-null  int64
#  10  Province                     405624 non-null  object
#  11  City                         405624 non-null  object
# ...
